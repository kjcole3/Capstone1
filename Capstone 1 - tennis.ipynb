# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
matches = pd.DataFrame.from_csv('data/tennismatches.csv',index_col=None, encoding='ISO-8859-1')
matches.head()
# Out:
#    atp  location                          tournament  day  month  year  \
# 0    1  Adelaide  Australian Hardcourt Championships    3      1  2000
# 1    1  Adelaide  Australian Hardcourt Championships    3      1  2000
# 2    1  Adelaide  Australian Hardcourt Championships    3      1  2000
# 3    1  Adelaide  Australian Hardcourt Championships    3      1  2000
# 4    1  Adelaide  Australian Hardcourt Championships    3      1  2000
#
#        date         series    court surface    ...       l2   w3   l3  w4  l4  \
# 0  1/3/2000  International  Outdoor    Hard    ...      2.0  NaN  NaN NaN NaN
# 1  1/3/2000  International  Outdoor    Hard    ...      3.0  NaN  NaN NaN NaN
# 2  1/3/2000  International  Outdoor    Hard    ...      5.0  6.0  3.0 NaN NaN
# 3  1/3/2000  International  Outdoor    Hard    ...      4.0  NaN  NaN NaN NaN
# 4  1/3/2000  International  Outdoor    Hard    ...      7.0  6.0  4.0 NaN NaN
#
#    w5  l5  wsets  lsets    comment
# ...

# %%
bracket = pd.DataFrame.from_csv('data/us_open_bracket.csv', index_col=None, encoding='ISO-8859-1')
bracket.head()
# Out:
#         Bracket
# 0    Djokovic N
# 1    Janowicz J
# 2      Veselý J
# 3      Myneni S
# 4  Fratangelo B

# %%
ranking = pd.DataFrame.from_csv('data/atp_rankings.csv', index_col=0, encoding='ISO-8859-1')
ranking.head()
# Out:
#              ATP First Name  Last Name
# Key
# Murray A       1       Andy     Murray
# Djokovic N     2      Novak   Djokovic
# Raonic M       3      Milos     Raonic
# Wawrinka S     4       Stan   Wawrinka
# Nishikori K    5        Kei  Nishikori

# %%
#Head to Head %
wins = matches[(matches.winner== player1) & (matches.loser== player2)]
wins = len(wins.index)
losses = matches[(matches.winner== player2) & (matches.loser== player1)].count()
losses = len(losses.index)
head2head = wins/(wins+losses)
# Do you add a multiplier for total matches played?

# %%
#World Rank Diff.
rank1 = rankings[rankings.index==player1].ATP
rank2 = rankings[ranking.index== player2].ATP
rankdiff = rank1 - rank2
